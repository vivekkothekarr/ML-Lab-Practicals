# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekkothekarr/ML-Lab-Practicals/blob/main/Practical_7_Vivek_Kothekar_(CS23110).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Vivek R. Kothekar (CS23110)**
#
# **Aim:-** To apply support Vector Machine for classification analyze the impact of different Kernels on model accuracy

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path= "/content/drive/MyDrive/ML/P_7.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df.shape
# Out:
# (17898, 9)

# %%
df.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# mean                                     0.477857
# std                                      1.064040
# min                                     -1.876011
# 25%                                      0.027098
# 50%                                      0.223240
# 75%                                      0.473325
# max                                      8.069522
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# count                         17898.000000               17898.000000
# mean                              1.770279                  12.614400
# std                               6.167913                  29.472897
# min                              -1.791886                   0.213211
# 25%                              -0.188572                   1.923077
# 50%                               0.198710                   2.801839
# 75%                               0.927783                   5.464256
# max                              68.101622                 223.392141
#
#         Standard deviation of the DM-SNR curve  \
# count                             17898.000000
# mean                                 26.326515
# std                                  19.470572
# min                                   7.370432
# 25%                                  14.437332
# 50%                                  18.461316
# 75%                                  28.428104
# max                                 110.642211
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# count                          17898.000000                   17898.000000
# mean                               8.303556                     104.857709
# std                                4.506092                     106.514540
# min                               -3.139270                      -1.976976
# 25%                                5.781506                      34.960504
# 50%                                8.433515                      83.064556
# 75%                               10.702959                     139.309330
# max                               34.539844                    1191.000837
#
#        target_class
# count  17898.000000
# mean       0.091574
# std        0.288432
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# Remove leading and trailing spaces from column names
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Mean of the integrated profile',
#        'Standard deviation of the integrated profile',
#        'Excess kurtosis of the integrated profile',
#        'Skewness of the integrated profile', 'Mean of the DM-SNR curve',
#        'Standard deviation of the DM-SNR curve',
#        'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Mean of the integrated profile': 'MIP',
    'Standard deviation of the integrated profile': 'SDIP',
    'Excess kurtosis of the integrated profile': 'EKIP',
    'Skewness of the integrated profile': 'SKIP',
    'Mean of the DM-SNR curve': 'MDSNR',
    'Standard deviation of the DM-SNR curve': 'SDSNR',
    'Excess kurtosis of the DM-SNR curve': 'EKSNR',
    'Skewness of the DM-SNR curve': 'SKSNR',
    'target_class': 'Target'
})

print(df.columns)
# Out:
# Index(['MIP', 'SDIP', 'EKIP', 'SKIP', 'MDSNR', 'SDSNR', 'EKSNR', 'SKSNR',
#        'Target'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 MIP          SDIP          EKIP          SKIP         MDSNR  \
# count  17898.000000  17898.000000  17898.000000  17898.000000  17898.000000
# mean     111.079968     46.549532      0.477857      1.770279     12.614400
# std       25.652935      6.843189      1.064040      6.167913     29.472897
# min        5.812500     24.772042     -1.876011     -1.791886      0.213211
# 25%      100.929688     42.376018      0.027098     -0.188572      1.923077
# 50%      115.078125     46.947479      0.223240      0.198710      2.801839
# 75%      127.085938     51.023202      0.473325      0.927783      5.464256
# max      192.617188     98.778911      8.069522     68.101622    223.392141
#
#               SDSNR         EKSNR         SKSNR        Target
# count  17898.000000  17898.000000  17898.000000  17898.000000
# mean      26.326515      8.303556    104.857709      0.091574
# std       19.470572      4.506092    106.514540      0.288432
# min        7.370432     -3.139270     -1.976976      0.000000
# 25%       14.437332      5.781506     34.960504      0.000000
# 50%       18.461316      8.433515     83.064556      0.000000
# 75%       28.428104     10.702959    139.309330      0.000000
# max      110.642211     34.539844   1191.000837      1.000000

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
df.columns
# Out:
# Index(['MIP', 'SDIP', 'EKIP', 'SKIP', 'MDSNR', 'SDSNR', 'EKSNR', 'SKSNR',
#        'Target'],
#       dtype='object')

# %%
print(df['Target'].value_counts())
# Out:
# Target
# 0    16259
# 1     1639
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.39398903,  0.27225212, -0.09759786, ..., -0.40338108,
#         -0.19481754, -0.37780071],
#        [-1.32725743, -1.52127273,  0.21878252, ..., -0.44578706,
#          0.23837256, -0.02857034],
#        [ 0.76130595,  0.98636783, -0.3245843 , ..., -0.2004973 ,
#          0.038556  , -0.29531727],
#        ...,
#        [ 0.19435365, -0.48635278,  0.17242235, ..., -0.75001383,
#          1.92294752,  1.91898259],
#        [ 0.95911539,  0.50175114, -0.53401036, ..., -0.24457614,
#         -0.20616758, -0.4040674 ],
#        [ 0.37725131,  0.58093396, -0.12507761, ..., -0.74159513,
#          2.05677923,  2.08022728]])

# %%
X_test
# Out:
# array([[ 0.22843774,  0.35277695, -0.27522748, ..., -0.43728381,
#         -0.04649179, -0.25085816],
#        [-1.38112247, -1.78437423,  1.44956147, ..., -0.22432742,
#         -0.28338031, -0.46408179],
#        [-0.30260453,  0.0698727 ,  0.02318325, ..., -0.54553131,
#          0.21981851, -0.00614623],
#        ...,
#        [ 0.97889633,  0.3533328 , -0.46793554, ..., -0.3882352 ,
#         -0.10691249, -0.33847727],
#        [-0.17691945,  0.37417406, -0.21925266, ..., -0.55602557,
#          0.1487237 , -0.05046816],
#        [-0.01410706, -1.21585526, -0.01840983, ..., -0.20872688,
#         -0.52776711, -0.61373985]])

# %%
X
# Out:
#               MIP       SDIP      EKIP      SKIP       MDSNR      SDSNR  \
# 0      140.562500  55.683782 -0.234571 -0.699648    3.199833  19.110426
# 1      102.507812  58.882430  0.465318 -0.515088    1.677258  14.860146
# 2      103.015625  39.341649  0.323328  1.051164    3.121237  21.744669
# 3      136.750000  57.178449 -0.068415 -0.636238    3.642977  20.959280
# 4       88.726562  40.672225  0.600866  1.123492    1.178930  11.468720
# ...           ...        ...       ...       ...         ...        ...
# 17893  136.429688  59.847421 -0.187846 -0.738123    1.296823  12.166062
# 17894  122.554688  49.485605  0.127978  0.323061   16.409699  44.626893
# 17895  119.335938  59.935939  0.159363 -0.743025   21.430602  58.872000
# 17896  114.507812  53.902400  0.201161 -0.024789    1.946488  13.381731
# 17897   57.062500  85.797340  1.406391  0.089520  188.306020  64.712562
#
#            EKSNR       SKSNR
# 0       7.975532   74.242225
# 1      10.576487  127.393580
# 2       7.735822   63.171909
# 3       6.896499   53.593661
# 4      14.269573  252.567306
# ...          ...         ...
# 17893  15.450260  285.931022
# 17894   2.945244    8.297092
# 17895   2.499517    4.595173
# 17896  10.007967  134.238910
# 17897  -1.597527    1.429475
#
# [17898 rows x 8 columns]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC()
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print('Model accuracy score with default hyperparameters: {0:0.4f}'. format(accuracy))
# Out:
# Model accuracy score with default hyperparameters: 0.9790

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
print('Confusion Matrix')
cm = confusion_matrix(y_pred,y_test)
print(confusion_matrix(y_pred,y_test))
# Out:
# Confusion Matrix
# [[4863   92]
#  [  21  394]]

# %%
print('Accuracy Score')
print(accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score
# 0.9789571694599628

# %%
print('Classification Report')
print(classification_report(y_pred,y_test))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      4955
#            1       0.81      0.95      0.87       415
#
#     accuracy                           0.98      5370
#    macro avg       0.90      0.97      0.93      5370
# weighted avg       0.98      0.98      0.98      5370

# %%
svc=SVC(C=100.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Model accuracy score with rbf kernel and c=100.0 : {0:.4f}'.format(accuracy))
# Out:
# Model accuracy score with rbf kernel and c=100.0 : 0.9790

# %%
svc=SVC(C=1000.0)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Model accuracy score with rbf kernel and c=100.0 : {0:.4f}'.format(accuracy))
# Out:
# Model accuracy score with rbf kernel and c=100.0 : 0.9790

# %% [markdown]
# SVM

# %%
linear_svc=SVC(kernel='linear',C=1.0)
linear_svc.fit(X_train,y_train)
y_pred_test=linear_svc.predict(X_test)
linear_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with linear kernel and c=1.0 : {0:.4f}'.format(linear_accuracy))
# Out:
# Model accuracy score with linear kernel and c=1.0 : 0.9788

# %%
linear_svc=SVC(kernel='linear',C=100.0)
linear_svc.fit(X_train,y_train)
y_pred_test=linear_svc.predict(X_test)
linear_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with linear kernel and c=100.0 : {0:.4f}'.format(linear_accuracy))
# Out:
# Model accuracy score with linear kernel and c=100.0 : 0.9786

# %%
linear_svc=SVC(kernel='linear',C=1000.0)
linear_svc.fit(X_train,y_train)
y_pred_test=linear_svc.predict(X_test)
linear_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with linear kernel and c=1000.0 : {0:.4f}'.format(linear_accuracy))
# Out:
# Model accuracy score with linear kernel and c=1000.0 : 0.9786

# %% [markdown]
# SVM with polynomial

# %%
sigmoid_svc=SVC(kernel='sigmoid',C=1.0)
sigmoid_svc.fit(X_train,y_train)
y_pred_test=sigmoid_svc.predict(X_test)
sigmoid_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with sigmoid kernel and c=1.0 : {0:.4f}'.format(sigmoid_accuracy))
# Out:
# Model accuracy score with sigmoid kernel and c=1.0 : 0.8773

# %%
poly_svc=SVC(kernel='poly',C=100.0)
poly_svc.fit(X_train,y_train)
y_pred_test=poly_svc.predict(X_test)
poly_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with polynomial kernel and c=100.0 : {0:.4f}'.format(poly_accuracy))
# Out:
# Model accuracy score with polynomial kernel and c=100.0 : 0.9793

# %% [markdown]
# svm with sigmoid

# %%
sigmoid_svc=SVC(kernel='sigmoid',C=1.0)
sigmoid_svc.fit(X_train,y_train)
y_pred_test=sigmoid_svc.predict(X_test)
sigmoid_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with sigmoid kernel and c=1.0 : {0:.4f}'.format(sigmoid_accuracy))
# Out:
# Model accuracy score with sigmoid kernel and c=1.0 : 0.8773

# %%
sigmoid_svc=SVC(kernel='sigmoid',C=100.0)
sigmoid_svc.fit(X_train,y_train)
y_pred_test=sigmoid_svc.predict(X_test)
sigmoid_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with sigmoid kernel and c=100.0 : {0:.4f}'.format(sigmoid_accuracy))
# Out:
# Model accuracy score with sigmoid kernel and c=100.0 : 0.8773

# %%
sigmoid_svc=SVC(kernel='sigmoid',C=1000.0)
sigmoid_svc.fit(X_train,y_train)
y_pred_test=sigmoid_svc.predict(X_test)
sigmoid_accuracy = accuracy_score(y_test,y_pred_test)
print('Model accuracy score with sigmoid kernel and c=1000.0 : {0:.4f}'.format(sigmoid_accuracy))
# Out:
# Model accuracy score with sigmoid kernel and c=1000.0 : 0.8773
